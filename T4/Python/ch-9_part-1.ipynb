# %% [markdown]
# # Adavance OOPS

# %% [markdown]
# ### 1> Inheritance
# ###  --> SINGLE LEVEL INHERITANCE
# ###  --> MULTI LEVEL INHERITANCE
# ###  --> MULTIPLE INHERITANCE

# %%
class P1:
    def __init__(self):
        print("This is Parent 1")
class P2:
    def __init__(self):
        print("This is Parent 2")
class C1(P1,P2):
    def __init__(self):
        super().__init__()
        print("This is Child 1")
class C2(P1,P2):
    def __init__(self):
        super().__init__()
        print("This is Child 2")
class GC(C1,C2):
    def __init__(self):
        super().__init__()
        print("This is Grand Child")

# %%
gc = GC()
# Out:
# This is Parent 1
# This is Child 2
# This is Child 1
# This is Grand Child

# %%
GC.__mro__
# Out:
# (__main__.GC, __main__.C1, __main__.C2, __main__.P1, __main__.P2, object)

# %%
print(gc)

# %%
class P1:
    def __init__(self):
        print("This is Parent 1")
class P2:
    def __init__(self):
        print("This is Parent 2")
class C1(P1,P2):
    def __init__(self):
        super().__init__()
        print("This is Child 1")
class C2(P2):
    def __init__(self):
        super().__init__()
        print("This is Child 2")
class GC(C1,C2):
    def __init__(self):
        super().__init__()
        print("This is Grand Child")

# %%
gc1 = GC()
# Out:
# This is Parent 1
# This is Child 1
# This is Grand Child

# %%
### TypeError: Cannot create a consistent method resolution
### order (MRO) for bases P2, P1
###

# %%
GC.__mro__ # MRO - METHOD RESOLUTION ORDER
# Out:
# (__main__.GC, __main__.C1, __main__.P1, __main__.C2, __main__.P2, object)

# %% [markdown]
# #### WAP TO CREATE AN ONLINE TECH SHOP WHERE A CUSTOMER OR A USER BUYS OR PURCHASES 4 PRODUCTS
# #### 1> SSD - 5000/-
# #### 2> Printer - 7000/-
# #### 3> pendrive - 300/-
# #### 4> keyboard - 800/-
# #### USING SINGLE LEVEL INHERITANCE AND ASK CUSTOMER TO PAY THE AMOUNT EITHER VIA CHECKOR CASH AND PRINT BILL DETAILS ACCORDINGLY WHERE IF USER SELECTS CASH PAYMENT THE BILL SHOULD DISPLAY DENOMINATIONS notes - 200/500/10 of it) IF USER SELECTS BILL PAYMENT THEN BILL SHOULD DISPLAY BANK NAME CHEQUE DETAILS

# %%
# # OWN's VERSION
class TechShop:
    def __inti__(self):
        print("      WELCOME TO TECH SHOP      ")
        print("--------------------------------")
class CASH(TechShop):
    def __init__(self):
        print("YOU HAVE SELECTED CASH METHOD")
        self.Payment()
    def Payment(self):
        cash_req=[5000,7000,300,800]
        total_bill=sum(cash_req)
        if total_bill>500:
            Cash_500=total_bill%500
            total_bill=total_bill//500
        elif total_bill>200 and total_bill<500:
            Cash_200=total_bill%200
            total_bill=total_bill//200
        elif total_bill>100 and total_bill<200:
            Cash_100=total_bill%100
            total_bill=total_bill//100
        elif total_bill>50 and total_bill<100:
            Cash_50=total_bill%50
            total_bill=total_bill//50
        elif total_bill>20 and total_bill<50:
            Cash_20=total_bill%20
            total_bill=total_bill//20
        elif total_bill>10 and total_bill<20:
            Cash_10=total_bill%10
            total_bill=total_bill//10
        else:
            print("Enter correct value")
        self.display()
    def display(self):
        print(f"500 - {Cash_500}\n 200 - {Cash_200}\n 100 - {Cash_100}\n 50 - {Cash_50}\n 20 - {Cash_20}\n 10 - {Cash_10}\n")
class Cheque(TechShop):
    def __init__(self):
        print("YOU HAVE SELECTED CHEQUE METHOD")
        self.Payment()
    def Payment(self):
        print("bank Name : ",Bn_name)
        print("bank Number : ",Bn_number)

# %% [markdown]
# ## bit.ly/project_c3
# ## pdsinroza@gmail.com
# ## ljiet_c3

# %%
# SIR AND OWN's MODIFIED VERSION
class TechShop:
    def __init__(self,items,price):
        self.total=0
        self.items=items
        self.price=price
        for i in self.price:
            self.total += i
    def display(self):
        print("\n ITEMS \t\t\t PRICE")
        for i in range(len(self.items)):
            print(self.items[i]+" \t\t\t "+self.price[i])
        print("-"*25)
        print("Total = "+self.total)
class Cash_payment(TechShop):
    def __init__(self,items,price,deno,value):
        TechShop.__init__(self,items,price)
        self.deno=deno
        self.value=value
    def show_cash_details(self):
        TechShop.display(self)
        for i in range(len(deno)):
            notes=value//deno[i]
            print(deno[i]," * ",notes," = ",deno[i]*notes)
            value=value%deno[i]
class Cheque_payment(TechShop):
    def __init__(self,items,price,Bn_name,Bn_number):
        super().__init__(self,items,price)
        self.Bn_name=Bn_name
        self.Bn_number=Bn_number
    def show_cash_details(self):
        TechShop.display(self)
        print("bank Name : ",Bn_name)
        print("bank Number : ",Bn_number)

# %%
items=["SSD","Printer","Pandrive","keyboard"]
price=[5000,7000,300,800]
deno=[500,200,100,50,20,10]
print(items)
value=[input(f"Quantity of {i+1} item : ") for i in range(4)]
try:
    print("-------------- THANKS FOR PURCHASING --------------")
    choice=int(input("Choose How Would you like to Pay?\n Enter 1 : For Cash Payment \n Enter 2 : For Cheque Payment\n"))
    if choice==1:
        cash=Cash_payment(items,price,deno,value)
    elif choice==2:
        chq=Cheque_payment(items,price,input("Enter Bank Name : "),input("Enter your bank Number : "))
    else:
        print("Enter a valid choice from 1 or 2")
except (TypeError,AssertionError,KeyError) as E:
    print(E)
    print("Billing Fail Please Repurchase")
else:
    print("Please Come Back Again")
# Out:
# ['SSD', 'Printer', 'Pandrive', 'keyboard']
# Quantity of 1 item :  3
# Quantity of 2 item :  1
# Quantity of 3 item :  5
# Quantity of 4 item :  2
# -------------- THANKS FOR PURCHASING --------------
# Choose How Would you like to Pay?
#  Enter 1 : For Cash Payment
#  Enter 2 : For Cheque Payment
#  2
# Enter Bank Name :  HDFC
# Enter your bank Number :  25463288569
# TechShop.__init__() takes 3 positional arguments but 4 were given
# Billing Fail Please Repurchase

# %% [markdown]
# ## WAP TO create research database Which has 3 classes named 'person','institude' which inherits the person and University data which inherits the institude all have a common method named display to print statistics the class person collects data like name,branch,theme,name of paper class institute collects data like name of institude, and total courses avaliable and class University data collects data like list of institutes and their specialization

# %%
class Person:
    def __init__(self,Name,Branch,Theme,NameOfPaper):
        self.Name=Name
        self.Branch=Branch
        self.Theme=Theme
        self.NameOfPaper=NameOfPaper
    def display(self):
        print("Name of Researcher : ",self.Name)
        print("Name of Branch : ",self.Branch)
        print("Name of Theme : ",self.Theme)
        print("Name of Research Topic : ",self.NameOfPaper)
class Institute(Person):
    def __init__(self,Name,Branch,Theme,NameOfPaper,instName,totalCourses):
        super().__init__(Name,Branch,Theme,NameOfPaper)
        self.instName=instName
        self.totalCourses=totalCourses
    def display(self):
        Person.display(self)
        print("Name of institute ",self.instName)
        print("Total courses : \n",[i for i in self.totalCourses])
class UniversityData(Institute):
    def __init__(self,Name,Branch,Theme,NameOfPaper,instName,totalCourses,uniName,specs):
        super().__init__(Name,Branch,Theme,NameOfPaper,instName,totalCourses)
        self.uniName=uniName
        self.specs=specs
    def display(self):
        Institute.display(self)
        print("List of INSTITUTes : \n",[i for i in self.uniName],"\nTheir Specialization Respectively : \n",[i for i in self.specs])

# %%
Data= UniversityData("HP","BioScience","Floura and Fauna","Types of Life in Floura and Fauna","LJ Institute of Technology",["Engineering","Psychology","LAW","BBA"],["LJ Institute of Technology","LJ Institute of Psychology","Lj Institute of LAW","LJ Institute of Commerce"],["Technology and computer APPS","Criminial Reading","Top Lawyers and Advocates","Top Business Mans"])

# %%
Data.display()
# Out:
# Name of Researcher :  HP
# Name of Branch :  BioScience
# Name of Theme :  Floura and Fauna
# Name of Research Topic :  Types of Life in Floura and Fauna
# Name of institute  LJ Institute of Technology
# Total courses :
#  ['Engineering', 'Psychology', 'LAW', 'BBA']
# List of INSTITUTes :
#  ['LJ Institute of Technology', 'LJ Institute of Psychology', 'Lj Institute of LAW', 'LJ Institute of Commerce']
# Their Specialization Respectively :
#  ['Technology and computer APPS', 'Criminial Reading', 'Top Lawyers and Advocates', 'Top Business Mans']

# %%
class Person:
    def __init__(self,Name,Branch,Theme,NameOfPaper):
        self.Name=Name
        self.Branch=Branch
        self.Theme=Theme
        self.NameOfPaper=NameOfPaper
    def display(self):
        print("Name of Researcher : ",self.Name)
        print("Name of Branch : ",self.Branch)
        print("Name of Theme : ",self.Theme)
        print("Name of Research Topic : ",self.NameOfPaper)
class Institute:
    def __init__(self,instName,totalCourses):
        self.instName=instName
        self.totalCourses=totalCourses
    def display(self):
        print("Name of institute ",self.instName)
        print("Total courses : \n"+"\n".join(" -- "+i for i in self.totalCourses))
class UniversityData(Person,Institute):
    def __init__(self,Name,Branch,Theme,NameOfPaper,instName,totalCourses,uniName,specs):
        Person.__init__(self,Name,Branch,Theme,NameOfPaper)
        Institute.__init__(self,instName,totalCourses)
        self.uniName=uniName
        self.specs=specs
    def display(self):
        Person.display(self)
        Institute.display(self)
        print("List of INSTITUTes : \n"+"\n".join(" -- "+i for i in self.uniName),"\nTheir Specialization Respectively : \n"+"\n".join(" -- "+i for i in self.specs))

# %%
Data= UniversityData("HP","BioScience","Floura and Fauna","Types of Life in Floura and Fauna","LJ Institute of Technology",["Engineering","Psychology","LAW","BBA"],["LJ Institute of Technology","LJ Institute of Psychology","LJ Institute of LAW","LJ Institute of Commerce"],["Technology and computer APPS","Criminial Reading","Top Lawyers and Advocates","Top Business Mans"])

# %%
Data.display()
# Out:
# Name of Researcher :  HP
# Name of Branch :  BioScience
# Name of Theme :  Floura and Fauna
# Name of Research Topic :  Types of Life in Floura and Fauna
# Name of institute  LJ Institute of Technology
# Total courses :
#  -- Engineering
#  -- Psychology
#  -- LAW
#  -- BBA
# List of INSTITUTes :
#  -- LJ Institute of Technology
#  -- LJ Institute of Psychology
#  -- LJ Institute of LAW
#  -- LJ Institute of Commerce
# Their Specialization Respectively :
#  -- Technology and computer APPS
#  -- Criminial Reading
#  -- Top Lawyers and Advocates
#  -- Top Business Mans

# %% [markdown]
# # Operator OverLoading

# %%
class OP:
    def __init__(self,x):
        self.x=x
    def __add__(self,A):
        # A Creates a object and Automatically Stores value of next or previous Operation
        return self.x-A.x

# %%
op=OP(8)
op1=OP(12)
op+op1
# Out:
# -4

# %% [markdown]
# ## __add__ for Addition Operators
# ## __sub__ for Subtration Operators
# ## __mul__ for Multiplication Operators
# ## __truediv__ for Division Operators
# ## __floordiv__ for Floor Division Operators
# ## __mod__ for modulus operators
# ## __pow__ for power operator

# %%
class Complex:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        Temp=Complex(self.x,self.y)
        Temp.x=self.x+other.x
        Temp.y=self.y+other.y
        return Temp
    def display(self):
        print(f"{self.x}+{self.y}j")

# %%
c1=Complex(3,5)
c2=Complex(4,2)

# %%
c3=c1+c2

# %%
c3.display()
# Out:
# 7+7j

# %%
class Complex:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        Temp=Complex(self.x,self.y)
        Temp.x=self.x+other.x
        Temp.y=self.y+other.y
        return Temp
    # Alternate Method of Display
    def __str__(self):
        return f"{self.x}+{self.y}j"

# %%
print(c3)
# Out:
# 7+7j

# %% [markdown]
# ## __eq__ for == opreator
# ## __gt__ for > opreator
# ## __lt__ for < opreator
# ## __ge__ for >= opreator
# ## __le__ for <= opreator
# ## __ne__ for != opreator

# %%
# write a pogram to fetch integer value as an object comapre two objects and show whether it is equal to , greater, or less than other object
class Comp:
    def __init__(self,x):
        self.x=x
    def __eq__(self,A):
        flag=False
        if self.x==A.x:
            flag=True
        return flag
    def __gt__(self,A):
        flag=False
        if self.x>A.x:
            flag=True
        return flag
    def __lt__(self,A):
        flag=False
        if self.x<A.x:
            flag=True
        return flag

# %%
a=Comp(5)
b=Comp(5)

# %%
a==b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
# WAP CLASS TO COMAPRE DATES
class Compare:
    def __init__(self,day,month,year):
        self.day=day
        self.month=month
        self.year=year
    def __eq__(self,A):
        if self.day==A.day and self.month==A.month and self.year==A.year:
            return True
        else:
            return False
    def __gt__(self,A):
        if self.year>A.year:
            return True
        else:
            if self.month>A.month:
                return True
            else:
                if self.day>A.day:
                    return True
                else:
                    return False
    def __lt__(self,A):
        if self.year<A.year:
            return True
        else:
            if self.month<A.month:
                return True
            else:
                if self.day<A.day:
                    return True
                else:
                    return False

# %%
d1=Compare(1,2,2026)
d2=Compare(5,2,2026)

# %%
d1<d2
# Out:
# True

# %% [markdown]
# # Abstration

# %%
from abc import ABC,abstractmethod

# %%
class Base(ABC):
    @abstractmethod
    def __init__(self):
        pass
    @abstractmethod
    def display(self):
        pass
class child(Base):
    def __init__(self):
        pass
    def display(self):
        pass

# %%
C = child()
