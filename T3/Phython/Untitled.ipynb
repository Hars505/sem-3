# %%
import mysql.connector as connector
conn=connector.connect(host="localhost",port="3306", user="HP" ,database="Life-Desk")
if conn.is_connected():
    print("Connection Successful")
query="Create Table User(id int, name varchar(30), city varchar(50) , age int)"
Qry=conn.cursor()
Qry.execute(query)
conn.commit()
print("Query Excecuted")
# Out:
# Connection Successful
# Query Excecuted
