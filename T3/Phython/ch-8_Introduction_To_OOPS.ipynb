# %% [markdown]
# # Introduction To OOPS

# %%
class Py:
    def display(self):
        print("HEllo World")

# %%
P=Py()

# %%
P.display()
# Out:
# HEllo World

# %%
class Car:
    def startengine(self):
        print("Car started ")
    def breaks(self):
        print("Break has been pushed")
    def clutch(self):
        print("Clutch has been pushed")

# %%
Car=Car()

# %%
Car.startengine()
Car.clutch()
Car.breaks()
# Out:
# Car started
# Clutch has been pushed
# Break has been pushed

# %%
class Students: # 
    def details(self):
        self.name=input("Enter Name")
        self.rollno=int(input("Enter roll Number"))
        self.batch=input("Enter Your Batch")
    def display(self):
        print(f'''name of student is {self.name}
        Roll number of student is {self.rollno}
        Batch of student is {self.batch}''')

# %%
s1=Students()
s2=Students()

# %%
s1.details()
# Out:
# Enter Name HP
# Enter roll Number 99
# Enter Your Batch C3

# %%
s2.details()
# Out:
# Enter Name KS
# Enter roll Number 865
# Enter Your Batch C5

# %%
s1.display()
s2.display()
# Out:
# name of student is HP
#         Roll number of student is 99
#         Batch of student is C3
# name of student is KS
#         Roll number of student is 865
#         Batch of student is C5

# %%
class Student:
    def details(self,name,rollno,batch):
        self.name=name
        self.rollno=rollno
        self.batch=batch
    def display(self):
        print(f'''name of student is {self.name}
        Roll number of student is {self.rollno}
        Batch of student is {self.batch}''')

# %%
st1=Student()
st2=Student()

# %%
st1.details("HP",99,"C3")
st2.details("PN",96,"C3")

# %%
st1.display()
# Out:
# name of student is HP
#         Roll number of student is 99
#         Batch of student is C3

# %%
st2.display()
# Out:
# name of student is PN
#         Roll number of student is 96
#         Batch of student is C3

# %%
class StudentST:
    def __init__(self,name,rollno,batch):
        self.name=name
        self.rollno=rollno
        self.batch=batch
    def display(self):
        print(f'''name of student is {self.name}
        Roll number of student is {self.rollno}
        Batch of student is {self.batch}''')
    def __del__(self):b     
        print("Destructor called")

# %%
s1=StudentST("HP",98,"C3")
s1=StudentST("NS",99,"C3")
# Out:
# Destructor called

# %%
s1.display()
s2.display()
# Out:
# name of student is NS
#         Roll number of student is 99
#         Batch of student is C3
# name of student is KS
#         Roll number of student is 865
#         Batch of student is C5

# %%
del s1
# Out:
# Destructor called

# %%
# WAP to create a class book which has 2 methods fiction and non-fiction both the methods are created to genrate an inventory of book also 
#create a method to display this books
class Book:
    def __init__(self):
        self.fict=list()
        self.nfict=list()
    def fictional(self,name,author):
        self.name=name
        self.author=author
        self.fict+=["Name : "+self.name, "Author : "+self.author]
    def non_fictional(self,name,author):
        self.name=name
        self.author=author
        self.nfict+=["Name : "+self.name, "Author : "+self.author]
    def display(self):
        print("\nfictional books\n")
        for i in self.fict: 
            print(i)
        print("\nNon fictional books\n")
        for i in self.nfict: 
            print(i)

# %%
b1=Book()
b1.non_fictional("Wings of fire","Ravindranath Tagore")
b1.fictional("Hell's Paradise","Kijmi Nakamoto")
b1.fictional("My last Moments","Louis Stepherd")

# %%
b1.display()
# Out:
# fictional books
#
# Name : Hell's Paradise
# Author : Kijmi Nakamoto
# Name : My last Moments
# Author : Louis Stepherd
#
# Non fictional books
#
# Name : Wings of fire
# Author : Ravindranath Tagore

# %% [markdown]
# #### WAP to create a class student which stores name of student and marks of student in constructor create to separate,methods
# #### one for entering marks of 3 different subjects and display the marksheet

# %%
class Student:
    def __init__(self,name,rn):
        self.name=name
        self.rn=rn
        print("Enter marks")
        self.marks(int(input("Enter marks of Python : ")),int(input("Enter marks of F.S.D. : ")),int(input("Enter marks of D.E. : ")))
    def marks(self,pyh,fsd,de):
        self.pyh=pyh
        self.fsd=fsd
        self.de=de
    def marksht(self):
        print("-------------------------------------------------")
        print(f"Name Of Student         : {self.name}")
        print(f"Roll Number of Student  : {self.rn}")
        print("-------------------------------------------------")
        print(f"Marks of Python     : {self.pyh}")
        print(f"Marks of D.E.       : {self.de}")
        print(f"Marks of F.S.D.     : {self.fsd}")
        print("-------------------------------------------------")
        per=round(((self.pyh+self.de+self.fsd)/75)*100,2)
        print(f"Total Percentage Of Three Subjects : {per} ")
        if (per>=70):
            print("congratulations - You got Distinction")
        elif (per<=70 and per>=40):
            print("congratulations - You got Pass")
        else:
            print("You have Failed")
        print("-------------------------------------------------")

# %%
stu1=Student(input("Enter Student name : "),input("Enter Student Roll Number : "))
stu2=Student(input("Enter Student name : "),input("Enter Student Roll Number : "))
# Out:
# Enter Student name :  HP
# Enter Student Roll Number :  99
# Enter marks
# Enter marks of Python :  24
# Enter marks of F.S.D. :  23
# Enter marks of D.E. :  21
# Enter Student name :  SV
# Enter Student Roll Number :  45
# Enter marks
# Enter marks of Python :  25
# Enter marks of F.S.D. :  24
# Enter marks of D.E. :  23

# %%
stu1.marksht()
# Out:
# -------------------------------------------------
# Name Of Student         : HP
# Roll Number of Student  :99
# -------------------------------------------------
# Marks of Python     : 24
# Marks of D.E.       : 21
# Marks of F.S.D.     : 23
# -------------------------------------------------
# Total Percentage Of Three Subjects : 90.67
# congratulations - You got Distinction
# -------------------------------------------------

# %%
stu2.marksht()
# Out:
# -------------------------------------------------
# Name Of Student         : SV
# Roll Number of Student  :45
# -------------------------------------------------
# Marks of Python     : 25
# Marks of D.E.       : 23
# Marks of F.S.D.     : 24
# -------------------------------------------------
# Total Percentage Of Three Subjects : 96.0
# congratulations - You got Distinction
# -------------------------------------------------

# %% [markdown]
# #### WAP To Create A class ATM and Create methods
# #### 1> to Genrate a pin
# #### 2> to withdraw , deposit money
# #### 3> to check balance
# #### 4> to change pin
# #### 5> Pogram should only terminate when user wants

# %%
class ATM:
    def __init__(self):
        self.amount=10000
        self.genratepin()
        self.choice()
    def genratepin(self):
        self.pin=input("Enter A 4 - digit pin")
        if len(self.pin)>4 and len(self.pin)<4:
            print("Enter a valid 4-digit pin")
            self.genratepin()
        self.choice()
    def withdraw(self,amount):
        pinchk=input("Enter your pin")
        if pinchk==self.pin:
            self.amount-=amount
            print("Money Withdrawed")
            print("Your Balance is %d"%self.amount)
        else:
            print("Enter a valid value")
        self.choice()
    def deposit(self,amount):
        pinchk=input("Enter your pin")
        if pinchk==self.pin:
            self.amount+=amount
            print("Money Deposited")
            print("Your Balance is %d"%self.amount)
        else:
            print("Enter a valid value")
        self.choice()
    def checkbalance(self):
        pinchk=input("Enter your pin")
        if pinchk==self.pin:
            print("Your Balance is %d"%self.amount)
        else:
            print("Enter a valid value")
        self.choice()
    def changepin(self):
        self.genratepin()
        self.choice()
    def exit(self):
        print("System Exiting...")
    def choice(self):
        A=True
        while(A):
            ch=int(input('''
            Enter 1 : TO withdraw money
            Enter 2 : To deposit money
            Enter 3 : TO change pin
            Enter 4 : TO check Balance
            Enter 5 : to Exit\n'''))
            if ch==1:
                self.withdraw(int(input("Enter Money you want to Withdraw")))
                break
            elif ch==2:
                self.deposit(int(input("Enter Money you want to deposit")))
                break
            elif ch==4:
                self.checkbalance()
                break
            elif ch==3:
                self.changepin()
                break
            elif ch==5:
                self.exit()
                break
            else:
                print("Enter a valid value")
                self.choice()
                break

# %%
cust1=ATM()
# Out:
# Enter A 4 - digit pin 1234
#
#             Enter 1 : TO withdraw money
#             Enter 2 : To deposit money
#             Enter 3 : TO change pin
#             Enter 4 : TO check Balance
#             Enter 5 : to Exit
#  5
# System Exiting...
#             Enter 1 : TO withdraw money
#             Enter 2 : To deposit money
#             Enter 3 : TO change pin
#             Enter 4 : TO check Balance
#             Enter 5 : to Exit
#  5
# System Exiting...
#             Enter 1 : TO withdraw money
#             Enter 2 : To deposit money
#             Enter 3 : TO change pin
#             Enter 4 : TO check Balance
#             Enter 5 : to Exit
#  5
# System existing....
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 cust1=ATM()
#
# Cell In[5], line 4, in ATM.__init__(self)
#       2 def __init__(self):
#       3     self.amount=10000
# ----> 4     self.genratepin()
#       5     self.choice()
#
# Cell In[5], line 11, in ATM.genratepin(self)
#       9     print("Enter a valid 4-digit pin")
#      10     self.genratepin()
# ---> 11 self.choice()
#
# Cell In[5], line 61, in ATM.choice(self)
#      59 else:
#      60     print("Enter a valid value")
# ---> 61 self.choice()
#
# Cell In[5], line 61, in ATM.choice(self)
#      59 else:
#      60     print("Enter a valid value")
# ---> 61 self.choice()
#
# Cell In[5], line 41, in ATM.choice(self)
#      40 def choice(self):
# ---> 41     ch=int(input('''
#      42         Enter 1 : TO withdraw money
#      43         Enter 2 : To deposit money
#      44         Enter 3 : TO change pin
#      45         Enter 4 : TO check Balance
#      46         Enter 5 : to Exit\n'''))
#      47     if ch==1:
#      48         self.withdraw(int(input("Enter Money you want to Withdraw")))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #### WAP TO CREATE A CLASS ANALYSIS to analysis any given statement it should have methods to count
# #### 1>number of characters
# #### 2> number of uppercase alphabets
# #### 3> number of lowercase alphabet
# #### 4> number of vowels
# #### 5> number of consonats
# #### 6> a method to display statistics
# #### it should provide a detailed answer in percenatge

# %%
class Analysis:
    def __init__(self):
        self.Stmt=input("Enter Statement : ")
    def upperCS(self):
        self.countUpper=0
        st=(self.Stmt).split()
        for i in st:
            for j in i:
               if j.isupper():
                   self.countUpper+=1
    def lowerCS(self):
        self.countLower=0
        st=(self.Stmt).split()
        for i in st:
            for j in i:
               if j.islower():
                   self.countLower+=1
    def isVowel(self):
        self.countVowel=0
        st=(self.Stmt).split()
        for i in st:
            for j in i.lower():
               if j in ('a','e','i','o','u') and j.isalpha():
                   self.countVowel+=1
    def isConosnats(self):
        self.countCons=0
        st=(self.Stmt).split()
        for i in st:
            for j in i.lower():
               if j.isalpha() and j not in ('a','e','i','o','u'):
                   self.countCons+=1
    def ttlChar(self):
        self.countCh=0
        st=self.Stmt
        for i in st:
            for j in i:
               self.countCh+=1
    def stats(self):
        print("---------------------------------------------------------------")
        print(f"Total number of characters : {self.countCh}\n")
        print(f"Total number of vowels : {self.countVowel}\n")
        print(f"Total number of consonants : {self.countCons}\n")
        print(f"Total number of Upper case characters : {self.countUpper}\n")
        print(f"Total number of lower case characters : {self.countLower}\n")
        print(f"stats --- percenatge of vowels {round((self.countVowel/self.countCh)*100,2)}")
        print(f"      --- percenatge of consonants {round((self.countCons/self.countCh)*100,2)}")
        print(f"      --- percenatge of upper case alphabets {round((self.countUpper/self.countCh)*100,2)}")
        print(f"      --- percenatge of lower case alphabets {round((self.countLower/self.countCh)*100,2)}")

# %%
A=Analysis()
A.upperCS()
A.lowerCS()
A.isVowel()
A.isConosnats()
A.ttlChar()
A.stats()
# Out:
# Enter Statement :  Python is a Very Easy Language
# ---------------------------------------------------------------
# Total number of characters : 30
#
# Total number of vowels : 10
#
# Total number of consonants : 15
#
# Total number of Upper case characters : 4
#
# Total number of lower case characters : 21
#
# stats --- percenatge of vowels 33.33
#       --- percenatge of consonants 50.0
#       --- percenatge of upper case alphabets 13.33
#       --- percenatge of lower case alphabets 70.0

# %% [markdown]
# #### WAP To find distance between a point from origin using oop

# %%
class Distance:
    def __init__(self):
        self.x1=int(input("Enter value of x-coordinate"))
        self.y1=int(input("Enter value of y-coordinate"))
        self.dist()
    def dist(self):
        self.Distance=round(((self.x1)**2+(self.y1)**2)**0.5,2)
        print(self.Distance)
    def __str__(self):
        return(f"x={self.x1} , y={self.y1}")

# %%
D=Distance()
# Out:
# Enter value of x-coordinate 4
# Enter value of y-coordinate 3
# 5.0

# %%
print(D)
# Out:
#  x=4 , y=3

# %% [markdown]
# # ERROR HANDLING

# %%
try:
    n=5//0
except Exception as e:
    print(e)
else:
    print(n)
finally:
    print("Code Completed")
# Out:
# integer division or modulo by zero
# Code Completed

# %%
try:
    a=0
    print(a)
except NameError as E:
    print(E)
else:
    print(a==5)
finally:
    print("Code completed")
# Out:
# 0
# False
# Code completed

# %% [markdown]
# #### TYPES OF ERROR
# #### 1> ValueError
# #### 2> IndexError
# #### 3> IndentError
# #### 4> SyntaxError
# #### 5> TypeError
# #### 6> FileNotFoundError
# #### 7> ZeroDivision
# #### 8> KeyError
# #### 9> NameError
# #### 10> AttributeError
# #### 11> OSError
# #### 12> PermissionError
# #### 13> ModuleNotFoundError
# #### 14> integer division or modulo by zero

# %%
try:
    def cal(x,y):
        return (x/y)
    cal(25,0)
except ZeroDivisionErro:
    print('z')
except (TypeError,ValueError):
    print(" kd")
# Out:
# z

# %%
class MyError(Exception):
    print("This is My ERROR")
# Out:
# This is My ERROR

# %%
raise MyError("This is MY ERROR")
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise MyError("This is MY ERROR")
#
# MyError: This is MY ERROR

# %%
try:
    raise MyError("This is MY ERROR")
except MyError as E:
    print(E)
# Out:
# This is MY ERROR
